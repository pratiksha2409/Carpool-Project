# %% [markdown]
# <a href="https://colab.research.google.com/github/pratiksha2409/Carpool-Project/blob/main/PD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
os.environ['KAGGLE_CONFIG_DIR'] = '/content'

# %%
# !kaggle datasets download -d paultimothymooney/chest-xray-pneumonia
# Out:
# Warning: Your Kaggle API key is readable by other users on this system! To fix this, you can run 'chmod 600 /content/kaggle.json'
# Downloading chest-xray-pneumonia.zip to /content
# 100% 2.29G/2.29G [01:47<00:00, 23.2MB/s]
# 100% 2.29G/2.29G [01:47<00:00, 22.9MB/s]

# %%
import zipfile
zip_ext = zipfile.ZipFile('/content/chest-xray-pneumonia.zip', 'r')
zip_ext.extractall('/content')
zip_ext.close()

# %%
import tensorflow as tf
from tensorflow import keras
from keras import Sequential
from keras.layers import Conv2D,Dense,Flatten,Dropout

# %%
train_ds = keras.utils.image_dataset_from_directory(
    '/content/chest_xray/train',
    image_size = (256,256),
    batch_size = 32,
    labels = 'inferred',
    label_mode = 'int'

)

test_ds = keras.utils.image_dataset_from_directory(
    '/content/chest_xray/test',
    image_size = (256,256),
    batch_size = 32,
    labels = 'inferred',
    label_mode = 'binary'

)

val_ds = keras.utils.image_dataset_from_directory(
    '/content/chest_xray/val',
    image_size = (256,256),
    batch_size = 32,
    labels = 'inferred',
    label_mode = 'binary'
)
# Out:
# Found 5216 files belonging to 2 classes.
# Found 624 files belonging to 2 classes.
# Found 16 files belonging to 2 classes.

# %%
import matplotlib.pyplot as plt

# %%
plt.pie([len(train_ds),len(test_ds),len(val_ds)],labels = ['train','test','val'],autopct= '%.1f%%',explode = (0.05, 0, 0))
# Out:
# ([<matplotlib.patches.Wedge at 0x7b3d3ceae740>,
#   <matplotlib.patches.Wedge at 0x7b3d3ceae650>,
#   <matplotlib.patches.Wedge at 0x7b3d3ceaf310>],
#  [Text(-1.0768670906484026, 0.40355578186719787, 'train'),
#   Text(1.023306276583389, -0.4035396688121763, 'test'),
#   Text(1.0998396687459067, -0.01878039011560862, 'val')],
#  [Text(-0.6086640077577927, 0.22809674627276397, '88.6%'),
#   Text(0.5581670599545757, -0.2201125466248234, '10.9%'),
#   Text(0.5999125465886763, -0.010243849153968337, '0.5%')])

# %%
print(train_ds.class_names)
print(val_ds.class_names)
print(test_ds.class_names)
# Out:
# ['NORMAL', 'PNEUMONIA']
# ['NORMAL', 'PNEUMONIA']
# ['NORMAL', 'PNEUMONIA']

# %%
data_iterator = train_ds.as_numpy_iterator()
batch = data_iterator.next()
fig, ax = plt.subplots(ncols=4, figsize=(20,20))
for idx, img in enumerate(batch[0][:4]):
    ax[idx].imshow(img.astype(int))
    ax[idx].title.set_text(batch[1][idx])

# %%
def process(image,label):
  image = tf.cast(image/255. ,tf.float32)
  return image,label
train_ds = train_ds.map(process)
test_ds = test_ds.map(process)
val_ds = val_ds.map(process)

# %%
from keras.applications.vgg16 import VGG16

# %%
conv_base = VGG16(
    include_top = False,
    weights = 'imagenet',
    input_shape=(256,256,3)
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 4s 0us/step

# %%
conv_base.trainable = True

set_trainable = False

for layer in conv_base.layers:
  if layer.name == 'block5_conv1':
    set_trainable = True
  if set_trainable:
    layer.trainable = True
  else:
    layer.trainable = False

for layer in conv_base.layers:
  print(layer.name,layer.trainable)
# Out:
# input_1 False
# block1_conv1 False
# block1_conv2 False
# block1_pool False
# block2_conv1 False
# block2_conv2 False
# block2_pool False
# block3_conv1 False
# block3_conv2 False
# block3_conv3 False
# block3_pool False
# block4_conv1 False
# block4_conv2 False
# block4_conv3 False
# block4_pool False
# block5_conv1 True
# block5_conv2 True
# block5_conv3 True
# block5_pool True

# %%
model = Sequential()

model.add(conv_base)
model.add(Flatten())



model.add(Dense(128, activation='relu', kernel_regularizer=keras.regularizers.l2(0.05)))
model.add(Dropout(0.3))



model.add(Dense(1, activation='sigmoid'))

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 8, 8, 512)         14714688
#
#  flatten (Flatten)           (None, 32768)             0
#
#  dense (Dense)               (None, 128)               4194432
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 18909249 (72.13 MB)
# Trainable params: 11273985 (43.01 MB)
# Non-trainable params: 7635264 (29.13 MB)
# _________________________________________________________________

# %%
keras.utils.plot_model(model, show_shapes=True)

# %%
history = model.fit(train_ds,epochs=10,validation_data =val_ds)
# Out:
# Epoch 1/10
# 163/163 [==============================] - 58s 261ms/step - loss: 0.9296 - accuracy: 0.8959 - val_loss: 0.3339 - val_accuracy: 0.8750
# Epoch 2/10
# 163/163 [==============================] - 41s 243ms/step - loss: 0.1688 - accuracy: 0.9615 - val_loss: 0.2592 - val_accuracy: 0.8750
# Epoch 3/10
# 163/163 [==============================] - 41s 243ms/step - loss: 0.1083 - accuracy: 0.9793 - val_loss: 0.2051 - val_accuracy: 0.8125
# Epoch 4/10
# 163/163 [==============================] - 40s 235ms/step - loss: 0.0886 - accuracy: 0.9831 - val_loss: 0.1048 - val_accuracy: 1.0000
# Epoch 5/10
# 163/163 [==============================] - 40s 238ms/step - loss: 0.0805 - accuracy: 0.9858 - val_loss: 0.4185 - val_accuracy: 0.8750
# Epoch 6/10
# 163/163 [==============================] - 40s 237ms/step - loss: 0.0461 - accuracy: 0.9931 - val_loss: 0.0517 - val_accuracy: 1.0000
# Epoch 7/10
# 163/163 [==============================] - 41s 240ms/step - loss: 0.0330 - accuracy: 0.9937 - val_loss: 0.0120 - val_accuracy: 1.0000
# Epoch 8/10
# 163/163 [==============================] - 41s 245ms/step - loss: 0.0398 - accuracy: 0.9906 - val_loss: 0.1122 - val_accuracy: 0.9375
# Epoch 9/10
# 163/163 [==============================] - 40s 238ms/step - loss: 0.0527 - accuracy: 0.9935 - val_loss: 0.1409 - val_accuracy: 0.9375
# Epoch 10/10
# 163/163 [==============================] - 40s 238ms/step - loss: 0.0312 - accuracy: 0.9942 - val_loss: 0.2087 - val_accuracy: 0.8750

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])

# %%
model.save('/content/prat_trained_model.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
from google.colab import files

files.download('/content/prat_trained_model.h5')
